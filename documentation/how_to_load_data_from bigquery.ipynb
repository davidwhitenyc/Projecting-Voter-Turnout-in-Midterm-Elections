# %% [markdown]
# # How to Load Data from Google BigQuery

# %%
# import pandas to use DataFrame functionality
import pandas as pd

# %%
# authenicate the Google Cloud API
import os

os.environ["GOOGLE_APPLICATION_CREDENTIALS"]=r"C:\Users\david\OneDrive\Documents\Code\political-data-354221-eaf22a72ba45.json"

# %%
# load the BigQuery extension
# %load_ext google.cloud.bigquery
# Out:
# The google.cloud.bigquery extension is already loaded. To reload it, use:
#   %reload_ext google.cloud.bigquery

# %%
# load data from BigQuery and assign it to a DataFrame variable named 'georgia'

# %%
# %%bigquery georgia
# SELECT * FROM `political-data-354221.datasources.georgia_midterm_elections_2006_through_2018`

# %%
# glimpse

georgia.head()
# Out:
#      state    county fips_code  election2018_registered_voters  \
# 0  Georgia   Appling     13001                           10613
# 1  Georgia  Atkinson     13003                            4252
# 2  Georgia     Bacon     13005                            6010
# 3  Georgia     Baker     13007                            2232
# 4  Georgia   Baldwin     13009                           23399
#
#    election2018_ballots_cast  election2014_registered_voters  \
# 0                       6827                           10682
# 1                       2527                            3791
# 2                       3836                            5051
# 3                       1297                            2067
# 4                      15690                           20626
#
#    election2014_ballots_cast  election2010_registered_voters  \
# 0                       4532                            9306
# 1                       1713                            3640
# 2                       2271                            5003
# 3                       1017                            2122
# 4                      10774                           20299
#
#    election2010_ballots_cast  election2006_registered_voters  ...  \
# 0                       5263                            8779  ...
# 1                       1492                            3539  ...
# 2                       2537                            5015  ...
# 3                       1269                            2149  ...
# 4                      11528                           18319  ...
#
#    census2010_household_income_less_than_10k_pct  \
# 0                                          0.293
# 1                                          0.302
# 2                                          0.325
# 3                                          0.353
# 4                                          0.294
#
#    census2010_household_income_20_to_40k_pct  \
# 0                                      0.241
# 1                                      0.261
# 2                                      0.251
# 3                                      0.259
# 4                                      0.240
#
#    census2010_household_income_40_to_60k_pct  \
# 0                                      0.188
# 1                                      0.190
# 2                                      0.138
# 3                                      0.171
# 4                                      0.168
#
#    census2010_income_60_to_100k_pct  \
# 0                             0.168
# 1                             0.184
# 2                             0.163
# 3                             0.139
# 4                             0.188
#
#    census2010_household_income_100_to_200k_pct  \
# 0                                        0.106
# 1                                        0.046
# 2                                        0.119
# 3                                        0.059
# 4                                        0.101
#
#    census2010_household_income_200k_or_more_pct  census2010_poverty_pct  \
# 0                                         0.004                   0.220
# 1                                         0.018                   0.280
# 2                                         0.003                   0.157
# 3                                         0.019                   0.299
# 4                                         0.009                   0.219
#
#    census2010_families_with_young_children_pct  \
# 0                                        0.251
# 1                                        0.457
# 2                                        0.379
# 3                                        0.453
# 4                                        0.301
#
#    census2010_married_households_pct  census2010_households_without_a_car_pct
# 0                              0.529                                    0.077
# 1                              0.464                                    0.077
# 2                              0.503                                    0.062
# 3                              0.472                                    0.140
# 4                              0.377                                    0.097
#
# [5 rows x 88 columns]

# %% [markdown]
# ---
